# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1=np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2=numpyDizisi1 ** 2

# %%
(benimFigur, benimEksen)=plt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,color="g",alpha=0.5) #alpha transparanlık katar
benimEksen.plot(numpyDizisi2,numpyDizisi1,color="b")

# %%
(yeniFigur,yeniEksen)=plt.subplots()
yeniEksen.plot(numpyDizisi1,numpyDizisi1+2,color="blue",linewidth=5.0)
yeniEksen.plot(numpyDizisi1,numpyDizisi1+3,color="yellow",linewidth=1.0)

yeniEksen.plot(numpyDizisi1,numpyDizisi1+4,color="#C96F23",linestyle="-.")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+5,color="#C96F23",linestyle=":")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+6,color="#C96F23",linestyle="--")

yeniEksen.plot(numpyDizisi1,numpyDizisi1+7,color="#000000",linestyle="--",marker="o",markersize=8,markerfacecolor="red")
yeniEksen.plot(numpyDizisi1,numpyDizisi1+8,color="#000000",linestyle="--",marker="+",markersize=4)

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# ## histogram

# %%
yeniDizi=np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([10, 28, 55, 95, 11, 55, 26, 86,  0, 63, 97, 34, 63, 54, 23,  8, 58,
#        98, 54, 35, 49, 35, 39,  8, 92, 95, 51,  0, 10, 53, 58,  3,  2,  4,
#        14, 60, 63, 56, 99, 21, 97, 51,  9,  4, 29, 31, 33, 96, 47, 99])

# %%
plt.hist(yeniDizi)
# Out:
# (array([ 9.,  4.,  5.,  6.,  2., 10.,  4.,  0.,  1.,  9.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x258fda067e0>,
#   <matplotlib.lines.Line2D at 0x258fda06a80>],
#  'caps': [<matplotlib.lines.Line2D at 0x258fda06db0>,
#   <matplotlib.lines.Line2D at 0x258fda052b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x258fda06540>],
#  'medians': [<matplotlib.lines.Line2D at 0x258fda072c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x258fda07590>],
#  'means': []}
